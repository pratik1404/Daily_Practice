# %% [markdown]
# ### What is Pandas?
# * Pandas is a Python library used to work with data easily.It's super useful when you’re working with tables, spreadsheets, CSV files, or any kind of structured data.
#
# ### What is it used for?
# * Reading data (from CSV, Excel, SQL, JSON, etc.)
#
# * Cleaning data (handling missing values, fixing columns)
#
# * Analyzing data (filtering, grouping, summarizing)
#
# * Visualizing simple data trends (with help of other libraries like Matplotlib)
#
# * Manipulating data (adding/deleting columns, changing values)

# %% [markdown]
# ### Pandas Library – Intermediate Overview
# #### 1. DataFrame and Series (Recap)
# * A Series is like a single column (1D).
#
# * A DataFrame is like a full Excel sheet with rows and columns (2D).
#
# #### 2. Indexing
# Pandas lets you control row and column indexing:
#
# * You can rename the index or set a specific column as the index.
#
# * There are two main ways to access data:
#
# * Label-based: using .loc (e.g., by row name)
#
# * Position-based: using .iloc (e.g., by row number)
#
# #### 3. Data Cleaning
# Real-world data is often messy. Pandas helps with:
#
# * Handling missing values
#
# * Fixing data types (like string vs number)
#
# * Removing duplicates
#
# * Replacing or renaming values or columns
#
# #### 4. Aggregation and Grouping
#  Pandas allows you to group data based on a column and then perform calculations like:
#
# * Sum, average, count, min, max
# * This is helpful in getting insights from categories (e.g., sales by region).
#
# #### 5. Merging and Joining
# You can combine multiple DataFrames using:
#
# * Merge (like SQL joins)
#
# * Concatenation (stacking data vertically or horizontally)
#
# * This is useful when working with data from different sources.
#
# #### 6. Data Transformation
# Pandas allows you to:
#
# * Add or remove columns
#
# * Apply functions to rows or columns
#
# * Reorder or sort data
#
# * Convert between data types
#
# You can also reshape your data using methods like:
#
# * pivot or pivot_table (turn columns into rows or vice versa)
#
# * melt (make wide data long)
#
# #### 7. Time Series Support
# Pandas is very good for handling time-based data:
#
# * Date/time parsing
#
# * Resampling (e.g., from daily to monthly)
#
# * Rolling averages and trends over time
#
# #### 8. Working with Files
# Pandas supports:
#
# * Reading/writing CSV, Excel, SQL, JSON, Parquet, and more
#
# * Useful for loading large datasets from disk or cloud

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in d:\python\venv\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in d:\python\venv\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\patil\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\python\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\python\venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\patil\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# %%
data = [1, 2, 3, 4, 5]
print("series\n" , pd.Series(data))
# Out:
# series
#  0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.DataFrame(data)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
## Create a series from dictionary 

dic = {
    "name":["pratik","Pushkar" , "Akshay" , "Vedant" , "Mayur" , "Jayesh"],
    "age" : [21,21,21,21,21,21],
    "City" : ["Pune","Pune","Pune","Pune","Pune","Pune"],
    "Address" : ["Kamgarnagar","Kamgarnagar","Kamgarnagar","nigdi","sara","sara"],
    "Sem" : ["VII","VII","VII","VII","VII","VII"]
}

print(pd.DataFrame(dic))
# Out:
#       name  age  City      Address  Sem
# 0   pratik   21  Pune  Kamgarnagar  VII
# 1  Pushkar   21  Pune  Kamgarnagar  VII
# 2   Akshay   21  Pune  Kamgarnagar  VII
# 3   Vedant   21  Pune        nigdi  VII
# 4    Mayur   21  Pune         sara  VII
# 5   Jayesh   21  Pune         sara  VII

# %%
df = pd.DataFrame(dic)
df
# Out:
#       name  age  City      Address  Sem
# 0   pratik   21  Pune  Kamgarnagar  VII
# 1  Pushkar   21  Pune  Kamgarnagar  VII
# 2   Akshay   21  Pune  Kamgarnagar  VII
# 3   Vedant   21  Pune        nigdi  VII
# 4    Mayur   21  Pune         sara  VII
# 5   Jayesh   21  Pune         sara  VII

# %%
import pandas as pd

# %%
dic1 = {
    "student1" : {"name" : "Pratik" , "age" : 21 , "city" : "Pune"},
    "student2" : {"name" : "Pushkar" , "age" : 21 , "city" : "Pune"},
    "student3" : {"name" : "Akshay" , "age" : 21 , "city" : "Pune"}
}

print(pd.Series(dic1))
# Out:
# student1     {'name': 'Pratik', 'age': 21, 'city': 'Pune'}
# student2    {'name': 'Pushkar', 'age': 21, 'city': 'Pune'}
# student3     {'name': 'Akshay', 'age': 21, 'city': 'Pune'}
# dtype: object

# %%
df = pd.DataFrame(dic1)
df
# Out:
#      student1 student2 student3
# name   Pratik  Pushkar   Akshay
# age        21       21       21
# city     Pune     Pune     Pune

# %%
import numpy as np

np.array(df)
# Out:
# array([['Pratik', 'Pushkar', 'Akshay'],
#        [21, 21, 21],
#        ['Pune', 'Pune', 'Pune']], dtype=object)

# %%
df = pd.read_csv(r"D:\python\1-python_basics\Sales_Data.csv")

# %%
df.head(10)
# Out:
#    Transaction ID        Date Product Category                 Product Name  \
# 0           10001  2024-01-01      Electronics                iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances             Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing             Levi's 501 Jeans
# 3           10004  2024-01-04            Books            The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products      Neutrogena Skincare Set
# 5           10006  2024-01-06           Sports  Wilson Evolution Basketball
# 6           10007  2024-01-07      Electronics          MacBook Pro 16-inch
# 7           10008  2024-01-08  Home Appliances         Blueair Classic 480i
# 8           10009  2024-01-09         Clothing             Nike Air Force 1
# 9           10010  2024-01-10            Books        Dune by Frank Herbert
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal
# 5           5       29.99         149.95           Asia    Credit Card
# 6           1     2499.99        2499.99  North America    Credit Card
# 7           2      599.99        1199.98         Europe         PayPal
# 8           6       89.99         539.94           Asia     Debit Card
# 9           2       25.99          51.98  North America    Credit Card

# %%
df.tail()
# Out:
#      Transaction ID        Date Product Category  \
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card

# %%
df.count()
# Out:
# Transaction ID      240
# Date                240
# Product Category    240
# Product Name        240
# Units Sold          240
# Unit Price          240
# Total Revenue       240
# Region              240
# Payment Method      240
# dtype: int64

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Product Category', 'Product Name',
#        'Units Sold', 'Unit Price', 'Total Revenue', 'Region',
#        'Payment Method'],
#       dtype='object')

# %%
df["Product Category"]
# Out:
# 0          Electronics
# 1      Home Appliances
# 2             Clothing
# 3                Books
# 4      Beauty Products
#             ...
# 235    Home Appliances
# 236           Clothing
# 237              Books
# 238    Beauty Products
# 239             Sports
# Name: Product Category, Length: 240, dtype: object

# %%
df["Payment Method"]
# Out:
# 0      Credit Card
# 1           PayPal
# 2       Debit Card
# 3      Credit Card
# 4           PayPal
#           ...
# 235         PayPal
# 236     Debit Card
# 237    Credit Card
# 238         PayPal
# 239    Credit Card
# Name: Payment Method, Length: 240, dtype: object

# %%
type(df["Payment Method"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Using loc[ ] (Label-Based)
# ```python
# df.loc['a']           # Row with label 'a'
# df.loc['a':'b']       # Rows 'a' and 'b' (inclusive)
# df.loc['a', 'Name']   # Value at row 'a' and column 'Name'
#
# ```
# ### Using iloc[ ] (Integer Position-Based)
# ```python
# df.iloc[0]            # First row
# df.iloc[0:2]          # First two rows (0 and 1)
# df.iloc[0, 1]         # Value at 1st row, 2nd column
# ```

# %%
df.loc[0]["Date"]
# Out:
# '2024-01-01'

# %%
df.loc[0]["Product Name"]
# Out:
# 'iPhone 14 Pro'

# %%
df.iloc[1][7]
# Out:
# C:\Users\patil\AppData\Local\Temp\ipykernel_16792\559840149.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[1][7]
# 'Europe'

# %%
df.iloc[0:]
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 0          1999.98  North America    Credit Card
# 1           499.99         Europe         PayPal
# 2           209.97           Asia     Debit Card
# 3            63.96  North America    Credit Card
# 4            89.99         Europe         PayPal
# ..             ...            ...            ...
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card
#
# [240 rows x 9 columns]

# %%
## accessing elemet using at 

df.at[3,"Region"]
# Out:
# 'North America'

# %%
## Accessing element using iat 

df.iat[23,8]
# Out:
# 'Credit Card'

# %% [markdown]
# #### Data manipulation using pandas

# %%
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue         Region Payment Method
# 0          1999.98  North America    Credit Card
# 1           499.99         Europe         PayPal
# 2           209.97           Asia     Debit Card
# 3            63.96  North America    Credit Card
# 4            89.99         Europe         PayPal
# ..             ...            ...            ...
# 235         159.99         Europe         PayPal
# 236         270.00           Asia     Debit Card
# 237          32.97  North America    Credit Card
# 238          55.00         Europe         PayPal
# 239          59.98           Asia    Credit Card
#
# [240 rows x 9 columns]

# %%
## Remove a column
df.drop('Region', axis = 1)   ### By default row is triggerred i.e axis = 0 ... so we chanege the axis to column i.e axis = 1
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# 5             10006  2024-01-06           Sports
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# 5                        Wilson Evolution Basketball           5       29.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue Payment Method
# 0          1999.98    Credit Card
# 2           209.97     Debit Card
# 3            63.96    Credit Card
# 4            89.99         PayPal
# 5           149.95    Credit Card
# ..             ...            ...
# 235         159.99         PayPal
# 236         270.00     Debit Card
# 237          32.97    Credit Card
# 238          55.00         PayPal
# 239          59.98    Credit Card
#
# [239 rows x 8 columns]

# %%
## for permanent operation 
try :
    df.drop("Region" , axis = 1 , inplace=True)
except :
    print("Column already deleted")

# %%
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# 5             10006  2024-01-06           Sports
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 2                                   Levi's 501 Jeans           3       69.99
# 3                                  The Da Vinci Code           4       15.99
# 4                            Neutrogena Skincare Set           1       89.99
# 5                        Wilson Evolution Basketball           5       29.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      159.99
# 236                        Nike Air Force 1 Sneakers           3       90.00
# 237           The Handmaid's Tale by Margaret Atwood           3       10.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       55.00
# 239                       Yeti Rambler 20 oz Tumbler           2       29.99
#
#      Total Revenue Payment Method
# 0          1999.98    Credit Card
# 2           209.97     Debit Card
# 3            63.96    Credit Card
# 4            89.99         PayPal
# 5           149.95    Credit Card
# ..             ...            ...
# 235         159.99         PayPal
# 236         270.00     Debit Card
# 237          32.97    Credit Card
# 238          55.00         PayPal
# 239          59.98    Credit Card
#
# [239 rows x 8 columns]

# %%
df["Unit Price"] = df["Unit Price"] + 10

# %%
df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# 5             10006  2024-01-06           Sports
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2     1009.99
# 2                                   Levi's 501 Jeans           3       79.99
# 3                                  The Da Vinci Code           4       25.99
# 4                            Neutrogena Skincare Set           1       99.99
# 5                        Wilson Evolution Basketball           5       39.99
# ..                                               ...         ...         ...
# 235  Nespresso Vertuo Next Coffee and Espresso Maker           1      169.99
# 236                        Nike Air Force 1 Sneakers           3      100.00
# 237           The Handmaid's Tale by Margaret Atwood           3       20.99
# 238             Sunday Riley Luna Sleeping Night Oil           1       65.00
# 239                       Yeti Rambler 20 oz Tumbler           2       39.99
#
#      Total Revenue Payment Method
# 0          1999.98    Credit Card
# 2           209.97     Debit Card
# 3            63.96    Credit Card
# 4            89.99         PayPal
# 5           149.95    Credit Card
# ..             ...            ...
# 235         159.99         PayPal
# 236         270.00     Debit Card
# 237          32.97    Credit Card
# 238          55.00         PayPal
# 239          59.98    Credit Card
#
# [239 rows x 8 columns]

# %%
df.describe()
# Out:
#        Transaction ID  Units Sold   Unit Price  Total Revenue
# count      239.000000  239.000000   239.000000     239.000000
# mean     10120.995816    2.163180   245.292678     335.011967
# std         69.144806    1.323092   430.007202     486.707016
# min      10001.000000    1.000000    16.500000       6.500000
# 25%      10061.500000    1.000000    39.500000      61.970000
# 50%      10121.000000    2.000000    99.990000     179.970000
# 75%      10180.500000    3.000000   259.990000     398.500000
# max      10240.000000   10.000000  3909.990000    3899.990000

# %%
df.dtypes
# Out:
# Transaction ID        int64
# Date                 object
# Product Category     object
# Product Name         object
# Units Sold            int64
# Unit Price          float64
# Total Revenue       float64
# Payment Method       object
# dtype: object

# %% [markdown]
# ## Part 2 of pandas

# %%
df = pd.read_csv(r"D:\python\1-python_basics\data.csv")

# %%
df.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df.describe()
# Out:
#            Value       Sales
# count  47.000000   46.000000
# mean   51.744681  557.130435
# std    29.050532  274.598584
# min     2.000000  108.000000
# 25%    27.500000  339.000000
# 50%    54.000000  591.500000
# 75%    70.000000  767.500000
# max    99.000000  992.000000

# %%
df.dtypes
# Out:
# Date         object
# Category     object
# Value       float64
# Product      object
# Sales       float64
# Region       object
# dtype: object

# %%
df.isnull().any(axis =1 )
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31    False
# 32    False
# 33     True
# 34    False
# 35     True
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
df_filled = df.fillna(0)

# %%
df
# Out:
#           Date Category  Value   Product  Sales Region
# 0   2023-01-01        A   28.0  Product1  754.0   East
# 1   2023-01-02        B   39.0  Product3  110.0  North
# 2   2023-01-03        C   32.0  Product2  398.0   East
# 3   2023-01-04        B    8.0  Product1  522.0   East
# 4   2023-01-05        B   26.0  Product3  869.0  North
# 5   2023-01-06        B   54.0  Product3  192.0   West
# 6   2023-01-07        A   16.0  Product1  936.0   East
# 7   2023-01-08        C   89.0  Product1  488.0   West
# 8   2023-01-09        C   37.0  Product3  772.0   West
# 9   2023-01-10        A   22.0  Product2  834.0   West
# 10  2023-01-11        B    7.0  Product1  842.0  North
# 11  2023-01-12        B   60.0  Product2    NaN   West
# 12  2023-01-13        A   70.0  Product3  628.0  South
# 13  2023-01-14        A   69.0  Product1  423.0   East
# 14  2023-01-15        A   47.0  Product2  893.0   West
# 15  2023-01-16        C    NaN  Product1  895.0  North
# 16  2023-01-17        C   93.0  Product2  511.0  South
# 17  2023-01-18        C    NaN  Product1  108.0   West
# 18  2023-01-19        A   31.0  Product2  578.0   West
# 19  2023-01-20        A   59.0  Product1  736.0   East
# 20  2023-01-21        C   82.0  Product3  606.0  South
# 21  2023-01-22        C   37.0  Product2  992.0  South
# 22  2023-01-23        B   62.0  Product3  942.0  North
# 23  2023-01-24        C   92.0  Product2  342.0   West
# 24  2023-01-25        A   24.0  Product2  458.0   East
# 25  2023-01-26        C   95.0  Product1  584.0   West
# 26  2023-01-27        C   71.0  Product2  619.0  North
# 27  2023-01-28        C   56.0  Product2  224.0  North
# 28  2023-01-29        B    NaN  Product3  617.0  North
# 29  2023-01-30        C   51.0  Product2  737.0  South
# 30  2023-01-31        B   50.0  Product3  735.0   West
# 31  2023-02-01        A   17.0  Product2  189.0   West
# 32  2023-02-02        B   63.0  Product3  338.0  South
# 33  2023-02-03        C   27.0  Product3    NaN   East
# 34  2023-02-04        C   70.0  Product3  669.0   West
# 35  2023-02-05        B   60.0  Product2    NaN   West
# 36  2023-02-06        C   36.0  Product3  177.0   East
# 37  2023-02-07        C    2.0  Product1    NaN  North
# 38  2023-02-08        C   94.0  Product1  408.0  South
# 39  2023-02-09        A   62.0  Product1  155.0   West
# 40  2023-02-10        B   15.0  Product1  578.0   East
# 41  2023-02-11        C   97.0  Product1  256.0   East
# 42  2023-02-12        A   93.0  Product3  164.0   West
# 43  2023-02-13        A   43.0  Product3  949.0   East
# 44  2023-02-14        A   96.0  Product3  830.0   East
# 45  2023-02-15        B   99.0  Product2  599.0   West
# 46  2023-02-16        B    6.0  Product1  938.0  South
# 47  2023-02-17        B   69.0  Product3  143.0   West
# 48  2023-02-18        C   65.0  Product3  182.0  North
# 49  2023-02-19        C   11.0  Product3  708.0  North

# %%
df["Sales_fillna"] = df["Sales"].fillna(df["Sales"].mean())

# %%
df["Sales_fillna"]
# Out:
# 0     754.000000
# 1     110.000000
# 2     398.000000
# 3     522.000000
# 4     869.000000
# 5     192.000000
# 6     936.000000
# 7     488.000000
# 8     772.000000
# 9     834.000000
# 10    842.000000
# 11    557.130435
# 12    628.000000
# 13    423.000000
# 14    893.000000
# 15    895.000000
# 16    511.000000
# 17    108.000000
# 18    578.000000
# 19    736.000000
# 20    606.000000
# 21    992.000000
# 22    942.000000
# 23    342.000000
# 24    458.000000
# 25    584.000000
# 26    619.000000
# 27    224.000000
# 28    617.000000
# 29    737.000000
# 30    735.000000
# 31    189.000000
# 32    338.000000
# 33    557.130435
# 34    669.000000
# 35    557.130435
# 36    177.000000
# 37    557.130435
# 38    408.000000
# 39    155.000000
# 40    578.000000
# 41    256.000000
# 42    164.000000
# 43    949.000000
# 44    830.000000
# 45    599.000000
# 46    938.000000
# 47    143.000000
# 48    182.000000
# 49    708.000000
# Name: Sales_fillna, dtype: float64

# %%
df.isnull().sum()
# Out:
# Date            0
# Category        0
# Value           3
# Product         0
# Sales           4
# Region          0
# Sales_fillna    0
# dtype: int64

# %%
df["Sales"].fillna(df["Sales"].mean(), inplace=True)
# Out:
# C:\Users\patil\AppData\Local\Temp\ipykernel_16792\1400562494.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Sales"].fillna(df["Sales"].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Date            0
# Category        0
# Value           3
# Product         0
# Sales           0
# Region          0
# Sales_fillna    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Category', 'Value', 'Product', 'Sales', 'Region',
#        'Sales_fillna'],
#       dtype='object')

# %%
# Renaming the columns 

df = df.rename(columns={"Date" : "Sale Date"})

# %%
## change datatype 

df["New Val"] = df["Value"].fillna(df["Value"].mean()).astype(int)

# %%
df.head()
# Out:
#     Sale Date Category  Value   Product  Sales Region  Sales_fillna  New Val
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0       28
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0       39
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0       32
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0        8
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0       26

# %%
df["New Val"] = df["New Val"].astype(float)
df.head()
# Out:
#     Sale Date Category  Value   Product  Sales Region  Sales_fillna  New Val  \
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0     28.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0     39.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0     32.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0      8.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0     26.0
#
#    val new
# 0     38.0
# 1     49.0
# 2     42.0
# 3     18.0
# 4     36.0

# %%
# apply operation by using . Apply("operation to be performed")

df["val new"] = df["Value"].fillna(df["Value"].mean()).apply(lambda x :x + 10 )
df.head()
# Out:
#     Sale Date Category  Value   Product  Sales Region  Sales_fillna  New Val  \
# 0  2023-01-01        A   28.0  Product1  754.0   East         754.0     28.0
# 1  2023-01-02        B   39.0  Product3  110.0  North         110.0     39.0
# 2  2023-01-03        C   32.0  Product2  398.0   East         398.0     32.0
# 3  2023-01-04        B    8.0  Product1  522.0   East         522.0      8.0
# 4  2023-01-05        B   26.0  Product3  869.0  North         869.0     26.0
#
#    val new
# 0     38.0
# 1     49.0
# 2     42.0
# 3     18.0
# 4     36.0

# %%
group_mean = df.groupby("Product")["Value"].sum()
group_mean
# Out:
# Product
# Product1    647.0
# Product2    792.0
# Product3    993.0
# Name: Value, dtype: float64

# %%
group_mean = df.groupby("Product")["Value"].mean()
group_mean
# Out:
# Product
# Product1    46.214286
# Product2    52.800000
# Product3    55.166667
# Name: Value, dtype: float64

# %%
grouperd_sum = df.groupby(["Product", "Region"])["Value"].sum()
print(grouperd_sum)
# Out:
# Product   Region
# Product1  East      292.0
#           North       9.0
#           South     100.0
#           West      246.0
# Product2  East       56.0
#           North     127.0
#           South     181.0
#           West      428.0
# Product3  East      202.0
#           North     203.0
#           South     215.0
#           West      373.0
# Name: Value, dtype: float64

# %%
## Aggregate Multiple Functions 

grouped_agg = df.groupby(["Region"])["Value"].agg(["mean" , "median" , "sum" , "count"])
grouped_agg
# Out:
#              mean  median     sum  count
# Region
# East    42.307692    32.0   550.0     13
# North   37.666667    39.0   339.0      9
# South   62.000000    66.5   496.0      8
# West    61.588235    60.0  1047.0     17

# %%
df1 = pd.DataFrame({"key" : ["a" , "b", "c"] , "Value1" : [1, 2, 3]})

df2 = pd.DataFrame({"key": ["a","b", "c"] , "Value2" : [4, 5, 6]})

# %%
df1
# Out:
#   key  Value1
# 0   a       1
# 1   b       2
# 2   c       3

# %%
df2
# Out:
#   key  Value2
# 0   a       4
# 1   b       5
# 2   c       6

# %%
merged_data = pd.merge(df1 , df2 , on = "key" , how = "inner")

# %%
merged_data
# Out:
#   key  Value1  Value2
# 0   a       1       4
# 1   b       2       5
# 2   c       3       6

# %%
df1 = pd.DataFrame({"key" : ["a" , "b" , "c" , "d"] , "Value1" : [1, 2, 3, 4]})

df2 = pd.DataFrame({"key" : ["a" , "b" , "e" , "f"], "Value2" : [5, 6, 7, 8]})

# %%
df1
# Out:
#   key  Value1
# 0   a       1
# 1   b       2
# 2   c       3
# 3   d       4

# %%
df2
# Out:
#   key  Value2
# 0   a       5
# 1   b       6
# 2   e       7
# 3   f       8

# %%
merged_new = pd.merge(df1 , df2 , on = "key" , how = "inner")
merged_new
# Out:
#   key  Value1  Value2
# 0   a       1       5
# 1   b       2       6

# %%
merged_new = pd.merge(df1 , df2 , on = "key" , how = "left")
merged_new
# Out:
#   key  Value1  Value2
# 0   a       1     5.0
# 1   b       2     6.0
# 2   c       3     NaN
# 3   d       4     NaN

# %%
merged_new = pd.merge(df1 , df2 , on = "key" , how = "right")
merged_new
# Out:
#   key  Value1  Value2
# 0   a     1.0       5
# 1   b     2.0       6
# 2   e     NaN       7
# 3   f     NaN       8

# %%
merged_new = pd.merge(df1 , df2 , on = "key" , how = "outer")
merged_new
# Out:
#   key  Value1  Value2
# 0   a     1.0     5.0
# 1   b     2.0     6.0
# 2   c     3.0     NaN
# 3   d     4.0     NaN
# 4   e     NaN     7.0
# 5   f     NaN     8.0

# %%
# !pip install lxml
# !pip install beautifulsoup4 
# !pip install html5lib
# !pip install openpyxl
# Out:
# Requirement already satisfied: lxml in d:\python\venv\lib\site-packages (6.0.0)
# Requirement already satisfied: beautifulsoup4 in d:\python\venv\lib\site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in d:\python\venv\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\python\venv\lib\site-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: html5lib in d:\python\venv\lib\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\patil\appdata\roaming\python\python312\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in d:\python\venv\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: openpyxl in d:\python\venv\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in d:\python\venv\lib\site-packages (from openpyxl) (2.0.0)

# %%
url = "https://www.fdic.gov/resources/resolutions/bank-failures/in-brief/index"

df = pd.read_html(url)
df
# Out:
# [     Years                       Bank Failures Total Assets (Millions)
#  0     2009                United Security Bank                  $157.0
#  1     2009                     Bank of Wyoming                   $70.0
#  2     2010                      Woodlands Bank                  $376.2
#  3     2016        The Woodbury Banking Company                   $21.4
#  4     2009      First State Bank of Winchester                   $36.0
#  ..     ...                                 ...                     ...
#  567   2023                      Signature Bank              $110,400.0
#  568   2023                 Silicon Valley Bank              $209,000.0
#  569   2024  The First National Bank of Lindsay                  $107.8
#  570   2025                Pulaski Savings Bank                   $49.5
#  571   2025        The Santa Anna National Bank                   $63.8
#
#  [572 rows x 3 columns]]

# %%
df[0]
# Out:
#      Years                       Bank Failures Total Assets (Millions)
# 0     2009                United Security Bank                  $157.0
# 1     2009                     Bank of Wyoming                   $70.0
# 2     2010                      Woodlands Bank                  $376.2
# 3     2016        The Woodbury Banking Company                   $21.4
# 4     2009      First State Bank of Winchester                   $36.0
# ..     ...                                 ...                     ...
# 567   2023                      Signature Bank              $110,400.0
# 568   2023                 Silicon Valley Bank              $209,000.0
# 569   2024  The First National Bank of Lindsay                  $107.8
# 570   2025                Pulaski Savings Bank                   $49.5
# 571   2025        The Santa Anna National Bank                   $63.8
#
# [572 rows x 3 columns]

# %%
url = "https://en.wikipedia.org/wiki/Mobile_country_code"
pd.read_html(url , match = "Country" , header = 0)[0]
# Out:
#      Mobile country code                                    Country ISO 3166  \
# 0                    289                                 A Abkhazia    GE-AB
# 1                    412                                Afghanistan       AF
# 2                    276                                    Albania       AL
# 3                    603                                    Algeria       DZ
# 4                    544  American Samoa (United States of America)       AS
# ..                   ...                                        ...      ...
# 247                  452                                    Vietnam       VN
# 248                  543                        W Wallis and Futuna       WF
# 249                  421                                    Y Yemen       YE
# 250                  645                                   Z Zambia       ZM
# 251                  648                                   Zimbabwe       ZW
#
#                                   Mobile network codes National MNC authority  \
# 0             List of mobile network codes in Abkhazia                    NaN
# 1          List of mobile network codes in Afghanistan                    NaN
# 2              List of mobile network codes in Albania                    NaN
# 3              List of mobile network codes in Algeria                    NaN
# 4       List of mobile network codes in American Samoa                    NaN
# ..                                                 ...                    ...
# 247        List of mobile network codes in the Vietnam                    NaN
# 248  List of mobile network codes in Wallis and Futuna                    NaN
# 249          List of mobile network codes in the Yemen                    NaN
# 250             List of mobile network codes in Zambia                    NaN
# 251           List of mobile network codes in Zimbabwe                    NaN
#
#                       Remarks
# 0    MCC is not listed by ITU
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 247                       NaN
# 248                       NaN
# 249                       NaN
# 250                       NaN
# 251                       NaN
#
# [252 rows x 6 columns]

# %%
pd.read_excel("data.xlsx")
# Out:
#        Name  Age
# 0    pratik   21
# 1    akshay   21
# 2   pushkar   21
# 3     nital   24
# 4  bhagwati   18
